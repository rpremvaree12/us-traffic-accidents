# %% [markdown]
# Reducing US Traffic Accidents

# %% [markdown]
# ## Overview
# Short project description. Your bottom line up front (BLUF) insights.

# %% [markdown]
# ## Business Understanding

# %% [markdown]
# ## Data Understanding

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('data/US_Accidents_March23.csv')
data.write_parquet('US_accident_data.parquet')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/p8/_r92c00j59v3wz7mp8x9d9740000gn/T/ipykernel_24575/4150844686.py in ?()
#       1 data = pd.read_csv('data/US_Accidents_March23.csv')
# ----> 2 data.write_parquet('US_accident_data.parquet')
#
# ~/Library/Python/3.11/lib/python/site-packages/pandas/core/generic.py in ?(self, name)
#    6317             and name not in self._accessors
#    6318             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6319         ):
#    6320             return self[name]
# -> 6321         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'write_parquet'

# %%
data.to_parquet("data/US_Accidents_March23.parquet")
