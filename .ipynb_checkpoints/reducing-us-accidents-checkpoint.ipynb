# %% [markdown]
# # Reducing US Traffic Accidents
# Analysis of US Car accident data from February 2016 to March 2023.

# %% [markdown]
# ## Overview
# Short project description. Your bottom line up front (BLUF) insights.

# %% [markdown]
# ## Business Understanding
# Why should we care?

# %% [markdown]
# ## Data Exploration

# %%
# import all necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('data/US_Accidents_March23.csv')

# %%
print(data.info())
print(data.describe())
print(data.isna().sum())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 print(data.info())
#       2 print(data.describe())
#       3 print(data.isna().sum())
#
# NameError: name 'data' is not defined
